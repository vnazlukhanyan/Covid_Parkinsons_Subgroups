# %%
import pandas as pd
import numpy as np

# %%
# %%time
df = pd.read_csv('/Users/victor/Desktop/694_Distributed_Computing/Final/FoxInsight/FoxInsight.csv')
df
# Out:
# <decorator-gen-54>:2: DtypeWarning: Columns (315,3205,3206,3207,3208,3209,3210,3211,3212,3213,3214,3215,3216,3217,3218,3219,3220,3221,3222,3223,3224) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 8min 6s, sys: 2min 23s, total: 10min 30s
# Wall time: 1h 14min 15s
#        fox_insight_id   age  SidePDOnset  NewPDDiagCTR  DiagAgeCTR  \
# 0          FOX_000076  82.1          NaN           NaN         NaN
# 1          FOX_000076  82.3          NaN           NaN         NaN
# 2          FOX_000076  82.6          NaN           NaN         NaN
# 3          FOX_000076  82.8          NaN           NaN         NaN
# 4          FOX_000076  83.1          NaN           NaN         NaN
# ...               ...   ...          ...           ...         ...
# 526420     FOX_999976  64.3          NaN           NaN         NaN
# 526421     FOX_999976  64.5          NaN           NaN         NaN
# ...

# %%
df_val = pd.read_csv('/Users/victor/Desktop/694_Distributed_Computing/Final/FoxInsight/FoxInsightValues.csv')
df_val
# Out:
#                 variable  value  \
# 0              COVPDDiag      1
# 1              COVPDDiag      2
# 2             COVSrcInfo      1
# 3             COVSrcInfo      2
# 4             COVSrcInfo      3
# ..                   ...    ...
# 604  COVRschPartcpLikely      5
# 605  COVRschPartcpLikely      6
# 606  COVRschPartcpLikely      7
# 607  COVRschPartcpLikely      1
# 608  COVRschPartcpLikely      4
#
#                                      value_description
# 0       I have been diagnosed with Parkinson's disease
# 1    I have not been diagnosed with Parkinson's dis...
# 2    The person registered to this Fox Insight acco...
# 3    Answering on behalf of the person registered f...
# 4                             Other (please describe):
# ..                                                 ...
# 604                                            Neutral
# 605                                    Somewhat likely
# 606                                        Very Likely
# ...

# %%
df_vars = pd.read_csv('/Users/victor/Desktop/694_Distributed_Computing/Final/FoxInsight/FoxInsightVariables.csv')
df_vars
# Out:
#                 variable                               variable_description  \
# 0              COVPDDiag  Please share your current health status: PD Di...
# 1             COVSrcInfo                                           Are you:
# 2          COVSympInfect  Have you had symptoms that you believe were du...
# 3            COVSympLast                   How long did your symptoms last?
# 4             COVProDiag  Have you been diagnosed with COVID-19 by a med...
# ..                   ...                                                ...
# 204   COVFinancePayBills                      Difficulty paying other bills
# 205      COVFinanceOther                           Other (please describe):
# 206   COVRschAttdtChange  Has the COVID-19 pandemic changed your likelih...
# 207  COVRschPartcpChance  How has the COVID-19 pandemic changed your lik...
# 208  COVRschPartcpLikely  After the COVID-19 pandemic is over, what is t...
#
#                                     category
# ...

# %%
# Can drop since only one value
df_vars['category'].unique()
# Out:
# array(['COVID-19 Experience in the PD Community'], dtype=object)

# %%
for question in df_vars['variable_description'].unique().tolist():
    print(question)
    print()
# Out:
# Please share your current health status: PD Diagnosis
#
# Are you:
#
# Have you had symptoms that you believe were due to infection with COVID-19?
#
# How long did your symptoms last?
#
# Have you been diagnosed with COVID-19 by a medical professional?
#
# When were you diagnosed or told you may have COVID-19 by a medical professional?
#
# Have you been tested for COVID-19?
#
# When were you tested for COVID-19?
#
# What was your COVID-19 test result?
#
# Whether or not you were diagnosed with COVID-19, have you experienced a fever anytime since the COVID-19 pandemic began (December 31, 2019)?
#
# What was your highest temperature during the COVID-19 pandemic?
#
# How many days did your fever last?
#
# Have you experienced a cough anytime since the COVID-19 pandemic began (December 31, 2019)?
#
# What kind of cough did you experience?
#
# Chills
#
# Excessive sweating
#
# Shortness of breath or have trouble breathing
#
# Chest tightness
#
# Chest pain
#
# ...
